# %%
from ultralytics import YOLO
import cv2
# Out:
# C:\Python311\Lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Python311\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Python311\Lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
model = YOLO(r"D:\jupyter-note-book\contest-uit\model\best.pt")

# %%
import os 
dir_ = r'Z:\init\frame-s'
list_dir = os.listdir(dir_)

# %%
list_dir
# Out:
# ['10_330.jpg',
#  '10_331.jpg',
#  '10_332.jpg',
#  '10_333.jpg',
#  '10_334.jpg',
#  '10_335.jpg',
#  '10_336.jpg',
#  '10_337.jpg',
#  '10_338.jpg',
#  '10_339.jpg',
#  '10_340.jpg',
#  '11_341.jpg',
#  '11_342.jpg',
#  '11_343.jpg',
#  '11_344.jpg',
#  '11_345.jpg',
#  '11_346.jpg',
#  '11_347.jpg',
#  '11_348.jpg',
#  '11_349.jpg',
#  '11_350.jpg',
#  '11_351.jpg',
#  '11_352.jpg',
#  '11_353.jpg',
#  '11_354.jpg',
#  '11_355.jpg',
#  '12_356.jpg',
#  '12_357.jpg',
#  '12_358.jpg',
#  '12_359.jpg',
#  '12_360.jpg',
#  '12_361.jpg',
#  '12_362.jpg',
#  '12_363.jpg',
#  '12_364.jpg',
#  '12_365.jpg',
#  '12_366.jpg',
#  '12_367.jpg',
#  '12_368.jpg',
#  '12_369.jpg',
#  '12_370.jpg',
#  '12_371.jpg',
#  '12_372.jpg',
#  '12_373.jpg',
#  '12_374.jpg',
#  '12_375.jpg',
#  '12_376.jpg',
#  '12_377.jpg',
#  '12_378.jpg',
#  '12_379.jpg',
#  '12_380.jpg',
#  '12_381.jpg',
#  '12_382.jpg',
#  '12_383.jpg',
#  '12_384.jpg',
#  '12_385.jpg',
#  '12_386.jpg',
#  '12_387.jpg',
# ...

# %%
len(list_dir)
# Out:
# 4867

# %%
for file in list_dir[3000:4000]:
    model.predict(os.path.join(dir_, file), save = True, save_txt = True)
